# %%
$Version
# Out:
# $MyPrePrint[$Version]
# 10.0 for Linux x86 (64-bit) (September 9, 2014)

# %% [markdown]
# ## Basics

# %%
a=2+2

b= 2*a;

c=Integrate[F[x],{x,0,b}]
# Out:
# $4$
# 4
# $\int_0^8 F(x) \, dx$
# Integrate[F[x], {x, 0, 8}]

# %% [markdown]
# ## Tables

# %%
Table[Cos[x],{x,{0,1,2,3,Pi,4}}]
# Out:
# $\{1,\cos (1),\cos (2),\cos (3),-1,\cos (4)\}$
# {1, Cos[1], Cos[2], Cos[3], -1, Cos[4]}

# %%
MatrixForm[Table[Cos[x],{x,{0,1,2,3,Pi,4}}]]
# Out:
# $\left( \begin{array}{c}  1 \\  \cos (1) \\  \cos (2) \\  \cos (3) \\  -1 \\  \cos (4) \\ \end{array} \right)$
# MatrixForm[{1, Cos[1], Cos[2], Cos[3], -1, Cos[4]}]

# %%
Table[Cos[x]+Sin[y],{x,{0,1,2,3,Pi,4}},{y,1,3}]
# Out:
# $\left( \begin{array}{ccc}  1+\sin (1) & 1+\sin (2) & 1+\sin (3) \\  \cos (1)+\sin (1) & \cos (1)+\sin (2) & \cos (1)+\sin (3) \\  \cos (2)+\sin (1) & \cos (2)+\sin (2) & \cos (2)+\sin (3) \\  \cos (3)+\sin (1) & \cos (3)+\sin (2) & \cos (3)+\sin (3) \\  -1+\sin (1) & -1+\sin (2) & -1+\sin (3) \\  \cos (4)+\sin (1) & \cos (4)+\sin (2) & \cos (4)+\sin (3) \\ \end{array} \right)$
# {{1 + Sin[1], 1 + Sin[2], 1 + Sin[3]}, {Cos[1] + Sin[1], Cos[1] + Sin[2], Cos[1] + Sin[3]}, {Cos[2] + Sin[1], Cos[2] + Sin[2], Cos[2] + Sin[3]}, {Cos[3] + Sin[1], Cos[3] + Sin[2], Cos[3] + Sin[3]}, {-1 + Sin[1], -1 + Sin[2], -1 + Sin[3]}, {Cos[4] + Sin[1], Cos[4] + Sin[2], Cos[4] + Sin[3]}}

# %%
MatrixForm[Table[Cos[x]+Sin[y],{x,{0,1,2,3,Pi,4}},{y,1,3}]]
# Out:
#                                                                                 ]
# $\left( \begin{array}{ccc}  1+\sin (1) & 1+\sin (2) & 1+\sin (3) \\  \sin (1)+\cos (1) & \sin (2)+\cos (1) & \sin (3)+\cos (1) \\  \sin (1)+\cos (2) & \sin (2)+\cos (2) & \sin (3)+\cos (2) \\  \sin (1)+\cos (3) & \sin (2)+\cos (3) & \sin (3)+\cos (3) \\  \sin (1)-1 & \sin (2)-1 & \sin (3)-1 \\  \sin (1)+\cos (4) & \sin (2)+\cos (4) & \sin (3)+\cos (4) \\ \end{array} \right)$
# MatrixForm[{{1 + Sin[1], 1 + Sin[2], 1 + Sin[3]}, {Cos[1] + Sin[1], Cos[1] + Sin[2], Cos[1] + Sin[3]}, {Cos[2] + Sin[1], Cos[2] + Sin[2], Cos[2] + Sin[3]}, {Cos[3] + Sin[1], Cos[3] + Sin[2], Cos[3] + Sin[3]}, {-1 + Sin[1], -1 + Sin[2], -1 + Sin[3]}, {Cos[4] + Sin[1], Cos[4] + Sin[2], Cos[4] + Sin[3]}}]

# %% [markdown]
# ## Linear Algebra

# %%
A={{1,2.,3.},{2,.3,2},{1,.3,1.}}

Eigensystem[A]
# Out:
# $\left( \begin{array}{ccc}  1 & 2. & 3. \\  2 & 0.3 & 2 \\  1 & 0.3 & 1. \\ \end{array} \right)$
# {{1, 2., 3.}, {2, 0.3, 2}, {1, 0.3, 1.}}
# $\left( \begin{array}{ccc}  3.8844 & -1.48004 & -0.104365 \\  \{-0.741056,-0.591149,-0.318402\} & \{-0.767447,0.595534,0.23741\} & \{-0.472646,-0.642981,0.602645\} \\ \end{array} \right)$
# {{3.8844037486842704, -1.4800390272297916, -0.10436472145447945}, {{-0.741055598256931, -0.5911486343738532, -0.31840209228268324}, {-0.7674473720243038, 0.5955340582699782, 0.23741043914175297}, {-0.47264575101293105, -0.6429811502189526, 0.602645197867315}}}

# %% [markdown]
# ## Plots

# %%
Plot[x,{x,0,2}]
# Out:
# - graphics -

# %%
Plot3D[x,{x,0,2},{y,0,2}]
# Out:
# /tmp/tmpmh3jrov2/session-figure28.jpg
# - graphics3d -

# %%
DensityPlot[x,{x,0,2},{y,0,2}]

# %%
ContourPlot[x,{x,0,2},{y,0,2}]
# Out:
# - graphics -

# %% [markdown]
# ## Sounds

# %%
Play[Sin[2*Pi*440. t],{t,0,2}]
# Out:
#                 <audio controls="controls" >
#                     <source src="/tmp/tmpmh3jrov2/session-sound16.wav" type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# - sound -
